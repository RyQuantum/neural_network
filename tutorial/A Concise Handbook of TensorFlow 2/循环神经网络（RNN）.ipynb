# %%
import tensorflow as tf
import numpy as np

# %%
class DataLoader():
    def __init__(self):
        path = tf.keras.utils.get_file('nietzsche.txt',
            origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
        with open(path, encoding='utf-8') as f:
            self.raw_text = f.read().lower()
        self.chars = sorted(list(set(self.raw_text)))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
        self.text = [self.char_indices[c] for c in self.raw_text]

    def get_batch(self, seq_length, batch_size):
        seq = []
        next_char = []
        for i in range(batch_size):
            index = np.random.randint(0, len(self.text) - seq_length)
            seq.append(self.text[index:index+seq_length])
            next_char.append(self.text[index+seq_length])
        return np.array(seq), np.array(next_char)       # [batch_size, seq_length], [num_batch]

# %%
data_loader = DataLoader()
data = data_loader.get_batch(3, 10)
print(data)
# Out:
# (array([[31, 51,  1],
#        [27, 45,  1],
#        [46, 35, 38],
#        [45, 51,  7],
#        [34, 31,  1],
#        [ 1, 34, 35],
#        [35, 40, 33],
#        [32,  1, 42],
#        [39, 31, 46],
#        [34, 35, 45]]), array([45, 46, 38,  1, 42, 46,  1, 34, 27,  1]))

# %%
class RNN(tf.keras.Model):
    def __init__(self, num_chars, batch_size, seq_length):
        super().__init__()
        self.num_chars = num_chars
        self.seq_length = seq_length
        self.batch_size = batch_size
        self.cell = tf.keras.layers.LSTMCell(units=256)
        self.dense = tf.keras.layers.Dense(units=self.num_chars)

    def call(self, inputs, from_logits=False):
        inputs = tf.one_hot(inputs, depth=self.num_chars)       # [batch_size, seq_length, num_chars]
        state = self.cell.get_initial_state(batch_size=self.batch_size, dtype=tf.float32)   # 获得 RNN 的初始状态
        for t in range(self.seq_length):
            output, state = self.cell(inputs[:, t, :], state)   # 通过当前输入和前一时刻的状态，得到输出和当前时刻的状态
        logits = self.dense(output)
        if from_logits:                     # from_logits 参数控制输出是否通过 softmax 函数进行归一化
            return logits
        else:
            return tf.nn.softmax(logits)
        
    def predict(self, inputs, temperature=1.):
        batch_size, _ = tf.shape(inputs)
        logits = self(inputs, from_logits=True)                         # 调用训练好的RNN模型，预测下一个字符的概率分布
        prob = tf.nn.softmax(logits / temperature).numpy()              # 使用带 temperature 参数的 softmax 函数获得归一化的概率分布值
        return np.array([np.random.choice(self.num_chars, p=prob[i, :]) # 使用 np.random.choice 函数，
                         for i in range(batch_size.numpy())])           # 在预测的概率分布 prob 上进行随机取样

# %%
num_batches = 1000
seq_length = 40
batch_size = 50
learning_rate = 1e-3

# %%
data_loader = DataLoader()
model = RNN(num_chars=len(data_loader.chars), batch_size=batch_size, seq_length=seq_length)
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
for batch_index in range(num_batches):
    X, y = data_loader.get_batch(seq_length, batch_size)
    with tf.GradientTape() as tape:
        y_pred = model(X)
        loss = tf.keras.losses.sparse_categorical_crossentropy(y_true=y, y_pred=y_pred)
        loss = tf.reduce_mean(loss)
        print("batch %d: loss %f" % (batch_index, loss.numpy()))
    grads = tape.gradient(loss, model.variables)
    optimizer.apply_gradients(grads_and_vars=zip(grads, model.variables))
# Out:
# batch 0: loss 4.041477
# batch 1: loss 4.030501
# batch 2: loss 4.000156
# batch 3: loss 3.986092
# batch 4: loss 3.963656
# batch 5: loss 3.868635
# batch 6: loss 3.748692
# batch 7: loss 3.448666
# batch 8: loss 3.370884
# batch 9: loss 3.535254
# batch 10: loss 3.085240
# batch 11: loss 3.052670
# batch 12: loss 2.872532
# batch 13: loss 3.320422
# batch 14: loss 3.072628
# batch 15: loss 3.245717
# batch 16: loss 3.285725
# batch 17: loss 2.965348
# batch 18: loss 3.219106
# batch 19: loss 2.889103
# batch 20: loss 3.113730
# batch 21: loss 3.089364
# batch 22: loss 3.125453
# batch 23: loss 2.995502
# batch 24: loss 3.132296
# batch 25: loss 2.962054
# batch 26: loss 3.227995
# batch 27: loss 2.915867
# batch 28: loss 2.866862
# batch 29: loss 2.974046
# batch 30: loss 3.257811
# batch 31: loss 2.903676
# batch 32: loss 3.065748
# batch 33: loss 2.829463
# batch 34: loss 2.878215
# batch 35: loss 3.409382
# batch 36: loss 3.154408
# batch 37: loss 2.985164
# batch 38: loss 3.131719
# batch 39: loss 3.208561
# batch 40: loss 3.121896
# batch 41: loss 2.995261
# batch 42: loss 3.080899
# batch 43: loss 2.939912
# batch 44: loss 2.998290
# batch 45: loss 3.042487
# batch 46: loss 3.013913
# batch 47: loss 3.005903
# batch 48: loss 2.910018
# batch 49: loss 2.774357
# batch 50: loss 3.063375
# batch 51: loss 3.060427
# batch 52: loss 2.884869
# batch 53: loss 3.038804
# batch 54: loss 3.004752
# batch 55: loss 3.148924
# batch 56: loss 3.013628
# batch 57: loss 2.974332
# batch 58: loss 2.985030
# batch 59: loss 2.927930
# batch 60: loss 2.896680
# batch 61: loss 3.027784
# batch 62: loss 2.950206
# batch 63: loss 2.879278
# batch 64: loss 3.282460
# batch 65: loss 3.276861
# batch 66: loss 3.250468
# batch 67: loss 3.167978
# batch 68: loss 2.872373
# batch 69: loss 2.868351
# batch 70: loss 3.042640
# batch 71: loss 3.402835
# batch 72: loss 3.027004
# batch 73: loss 3.195226
# batch 74: loss 3.125801
# batch 75: loss 2.872480
# batch 76: loss 3.147688
# batch 77: loss 3.094554
# batch 78: loss 2.822139
# batch 79: loss 3.158563
# batch 80: loss 3.050004
# batch 81: loss 3.086516
# batch 82: loss 2.803481
# batch 83: loss 2.834699
# batch 84: loss 3.189887
# batch 85: loss 3.183672
# batch 86: loss 2.861929
# batch 87: loss 3.084369
# batch 88: loss 3.014096
# batch 89: loss 2.804110
# batch 90: loss 3.226108
# batch 91: loss 2.911596
# batch 92: loss 3.073442
# batch 93: loss 2.815202
# batch 94: loss 3.032810
# batch 95: loss 2.955590
# batch 96: loss 2.843857
# batch 97: loss 3.134887
# batch 98: loss 3.104807
# batch 99: loss 3.040006
# batch 100: loss 3.221430
# batch 101: loss 3.242019
# batch 102: loss 2.940870
# batch 103: loss 2.976947
# batch 104: loss 2.960103
# batch 105: loss 2.810122
# batch 106: loss 3.026169
# batch 107: loss 3.006456
# batch 108: loss 2.922657
# batch 109: loss 3.029777
# batch 110: loss 2.875735
# batch 111: loss 3.059107
# batch 112: loss 3.014631
# batch 113: loss 3.033444
# batch 114: loss 2.983066
# batch 115: loss 3.034494
# batch 116: loss 2.835159
# batch 117: loss 3.129098
# batch 118: loss 2.916030
# batch 119: loss 2.975281
# batch 120: loss 2.864002
# batch 121: loss 2.985130
# batch 122: loss 3.072819
# batch 123: loss 3.076998
# batch 124: loss 3.148847
# batch 125: loss 3.122875
# batch 126: loss 2.857625
# batch 127: loss 3.205415
# batch 128: loss 2.977043
# batch 129: loss 2.884827
# batch 130: loss 3.195256
# batch 131: loss 3.031043
# batch 132: loss 2.947843
# batch 133: loss 2.881880
# batch 134: loss 2.961267
# batch 135: loss 2.897418
# batch 136: loss 3.011961
# batch 137: loss 2.737950
# batch 138: loss 3.028707
# batch 139: loss 2.883963
# batch 140: loss 3.053967
# batch 141: loss 2.924089
# batch 142: loss 2.800884
# batch 143: loss 3.016732
# batch 144: loss 3.127359
# batch 145: loss 2.919525
# batch 146: loss 3.081051
# batch 147: loss 2.903462
# batch 148: loss 3.061604
# batch 149: loss 2.904490
# batch 150: loss 2.994054
# batch 151: loss 2.824689
# batch 152: loss 2.719440
# batch 153: loss 2.985851
# batch 154: loss 2.961305
# batch 155: loss 2.861285
# batch 156: loss 2.734451
# batch 157: loss 3.079360
# batch 158: loss 3.000039
# batch 159: loss 2.782763
# batch 160: loss 2.818015
# batch 161: loss 2.795887
# batch 162: loss 2.755295
# batch 163: loss 2.916596
# batch 164: loss 3.122653
# batch 165: loss 3.026653
# batch 166: loss 2.825157
# batch 167: loss 2.938051
# batch 168: loss 3.174073
# batch 169: loss 3.119523
# batch 170: loss 2.852711
# batch 171: loss 2.806231
# batch 172: loss 2.900259
# batch 173: loss 3.034067
# batch 174: loss 2.789757
# batch 175: loss 2.842494
# batch 176: loss 3.176242
# batch 177: loss 3.068037
# batch 178: loss 2.854680
# batch 179: loss 3.354491
# batch 180: loss 3.068012
# batch 181: loss 3.080476
# batch 182: loss 3.034203
# batch 183: loss 2.947439
# batch 184: loss 2.879838
# batch 185: loss 3.093380
# batch 186: loss 3.093235
# batch 187: loss 2.999075
# batch 188: loss 2.750243
# batch 189: loss 2.804570
# batch 190: loss 2.889958
# batch 191: loss 2.918847
# batch 192: loss 2.994051
# batch 193: loss 2.838848
# batch 194: loss 2.965836
# batch 195: loss 2.877890
# batch 196: loss 2.916495
# batch 197: loss 2.702708
# batch 198: loss 3.275890
# batch 199: loss 2.783164
# batch 200: loss 2.894451
# batch 201: loss 2.937093
# batch 202: loss 2.957537
# batch 203: loss 3.132543
# batch 204: loss 2.855610
# batch 205: loss 2.819593
# batch 206: loss 3.299461
# batch 207: loss 3.050361
# batch 208: loss 2.866939
# batch 209: loss 3.041693
# batch 210: loss 2.975118
# batch 211: loss 2.830437
# batch 212: loss 3.181335
# batch 213: loss 3.224871
# batch 214: loss 2.866787
# batch 215: loss 2.976914
# batch 216: loss 3.105180
# batch 217: loss 3.164542
# batch 218: loss 2.753242
# batch 219: loss 3.035230
# batch 220: loss 3.019973
# batch 221: loss 2.771251
# batch 222: loss 3.218215
# batch 223: loss 2.995592
# batch 224: loss 3.071136
# batch 225: loss 2.828053
# batch 226: loss 3.035904
# batch 227: loss 3.086826
# batch 228: loss 2.978349
# batch 229: loss 2.800130
# batch 230: loss 3.056968
# batch 231: loss 3.177617
# batch 232: loss 3.136483
# batch 233: loss 3.048643
# batch 234: loss 2.916840
# batch 235: loss 2.899096
# batch 236: loss 2.684545
# batch 237: loss 3.145008
# batch 238: loss 2.741286
# batch 239: loss 2.685384
# batch 240: loss 2.859774
# batch 241: loss 3.008791
# batch 242: loss 2.994060
# batch 243: loss 2.702921
# batch 244: loss 3.003596
# batch 245: loss 2.824594
# batch 246: loss 2.841224
# batch 247: loss 2.934081
# batch 248: loss 2.880028
# batch 249: loss 3.004331
# batch 250: loss 2.950850
# batch 251: loss 3.012921
# batch 252: loss 3.069103
# batch 253: loss 2.722524
# batch 254: loss 2.889434
# batch 255: loss 2.935008
# batch 256: loss 2.814476
# batch 257: loss 2.845136
# batch 258: loss 2.889253
# batch 259: loss 2.965980
# batch 260: loss 2.724103
# batch 261: loss 3.015963
# batch 262: loss 2.984794
# batch 263: loss 3.143415
# batch 264: loss 3.086212
# batch 265: loss 2.768170
# batch 266: loss 2.744407
# batch 267: loss 2.664083
# batch 268: loss 2.766468
# batch 269: loss 2.915052
# batch 270: loss 2.794663
# batch 271: loss 2.897622
# batch 272: loss 2.959739
# batch 273: loss 2.808336
# batch 274: loss 2.694991
# batch 275: loss 2.897270
# batch 276: loss 2.994257
# batch 277: loss 2.809491
# batch 278: loss 2.658633
# batch 279: loss 3.083921
# batch 280: loss 2.724843
# batch 281: loss 2.511002
# batch 282: loss 2.968202
# batch 283: loss 2.969587
# batch 284: loss 2.935170
# batch 285: loss 2.906085
# batch 286: loss 2.854080
# batch 287: loss 2.732212
# batch 288: loss 2.748135
# batch 289: loss 3.020647
# batch 290: loss 2.801968
# batch 291: loss 2.933229
# batch 292: loss 2.862285
# batch 293: loss 3.085735
# batch 294: loss 2.850513
# batch 295: loss 2.806460
# batch 296: loss 2.848792
# batch 297: loss 2.745229
# batch 298: loss 2.913158
# batch 299: loss 2.825667
# batch 300: loss 2.903494
# batch 301: loss 2.839388
# batch 302: loss 2.955527
# batch 303: loss 2.972715
# batch 304: loss 2.638956
# batch 305: loss 2.941292
# batch 306: loss 2.807405
# batch 307: loss 2.883568
# batch 308: loss 2.907005
# batch 309: loss 2.587626
# batch 310: loss 2.784703
# batch 311: loss 2.780705
# batch 312: loss 2.732210
# batch 313: loss 2.861092
# batch 314: loss 2.682006
# batch 315: loss 2.836819
# batch 316: loss 2.772746
# batch 317: loss 2.928164
# batch 318: loss 2.642744
# batch 319: loss 2.848999
# batch 320: loss 2.690651
# batch 321: loss 2.535165
# batch 322: loss 3.326565
# batch 323: loss 2.676657
# batch 324: loss 2.731280
# batch 325: loss 2.662911
# batch 326: loss 2.921163
# batch 327: loss 2.759279
# batch 328: loss 2.730361
# batch 329: loss 2.689051
# batch 330: loss 2.930340
# batch 331: loss 2.883384
# batch 332: loss 2.549080
# batch 333: loss 2.626324
# batch 334: loss 2.882264
# batch 335: loss 2.695253
# batch 336: loss 2.965466
# batch 337: loss 2.770662
# batch 338: loss 2.704488
# batch 339: loss 2.824452
# batch 340: loss 2.646565
# batch 341: loss 2.725245
# batch 342: loss 2.540734
# batch 343: loss 2.776043
# batch 344: loss 2.626091
# batch 345: loss 2.748517
# batch 346: loss 2.646812
# batch 347: loss 2.657919
# batch 348: loss 3.020450
# batch 349: loss 2.818867
# batch 350: loss 2.539534
# batch 351: loss 2.687547
# batch 352: loss 2.718998
# batch 353: loss 2.800939
# batch 354: loss 2.847640
# batch 355: loss 2.488762
# batch 356: loss 2.809665
# batch 357: loss 2.609550
# batch 358: loss 2.737561
# batch 359: loss 2.665220
# batch 360: loss 2.670155
# batch 361: loss 2.662050
# batch 362: loss 2.998278
# batch 363: loss 2.894686
# batch 364: loss 2.737760
# batch 365: loss 2.600886
# batch 366: loss 2.608063
# batch 367: loss 2.974497
# batch 368: loss 2.862653
# batch 369: loss 3.058829
# batch 370: loss 2.584889
# batch 371: loss 2.558110
# batch 372: loss 2.848011
# batch 373: loss 2.474935
# batch 374: loss 2.576438
# batch 375: loss 2.796215
# batch 376: loss 2.656007
# batch 377: loss 3.056354
# batch 378: loss 2.780897
# batch 379: loss 2.802773
# batch 380: loss 2.680822
# batch 381: loss 2.576728
# batch 382: loss 2.497678
# batch 383: loss 2.572983
# batch 384: loss 2.553920
# batch 385: loss 2.800570
# batch 386: loss 2.774444
# batch 387: loss 2.832750
# batch 388: loss 2.820877
# batch 389: loss 2.484020
# batch 390: loss 2.584321
# batch 391: loss 2.824709
# batch 392: loss 2.633995
# batch 393: loss 2.721270
# batch 394: loss 2.752573
# batch 395: loss 2.434471
# batch 396: loss 2.593173
# batch 397: loss 2.723425
# batch 398: loss 3.028446
# batch 399: loss 2.524421
# batch 400: loss 2.855453
# batch 401: loss 2.299511
# batch 402: loss 2.435846
# batch 403: loss 2.612897
# batch 404: loss 2.610518
# batch 405: loss 2.648032
# batch 406: loss 2.464793
# batch 407: loss 2.630193
# batch 408: loss 2.469389
# batch 409: loss 3.089875
# batch 410: loss 2.749130
# batch 411: loss 2.492931
# batch 412: loss 2.681355
# batch 413: loss 2.705993
# batch 414: loss 2.729790
# batch 415: loss 2.782489
# batch 416: loss 2.366563
# batch 417: loss 2.669807
# batch 418: loss 2.682232
# batch 419: loss 2.852163
# batch 420: loss 2.435570
# batch 421: loss 2.888492
# batch 422: loss 2.802480
# batch 423: loss 2.905598
# batch 424: loss 2.460168
# batch 425: loss 2.544436
# batch 426: loss 2.691612
# batch 427: loss 2.408560
# batch 428: loss 3.055606
# batch 429: loss 2.705849
# batch 430: loss 2.659163
# batch 431: loss 2.608104
# batch 432: loss 2.566853
# batch 433: loss 2.447393
# batch 434: loss 2.624990
# batch 435: loss 2.545268
# batch 436: loss 2.826454
# batch 437: loss 2.763535
# batch 438: loss 2.489439
# batch 439: loss 2.614209
# batch 440: loss 2.599989
# batch 441: loss 2.565325
# batch 442: loss 2.518155
# batch 443: loss 2.899599
# batch 444: loss 2.624818
# batch 445: loss 2.561901
# batch 446: loss 2.692424
# batch 447: loss 2.565877
# batch 448: loss 2.208447
# batch 449: loss 2.701299
# batch 450: loss 2.566853
# batch 451: loss 2.699302
# batch 452: loss 2.613957
# batch 453: loss 2.417471
# batch 454: loss 2.798459
# batch 455: loss 2.530871
# batch 456: loss 2.895070
# batch 457: loss 2.558401
# batch 458: loss 2.585443
# batch 459: loss 2.495152
# batch 460: loss 2.459093
# batch 461: loss 2.577188
# batch 462: loss 2.477092
# batch 463: loss 2.453378
# batch 464: loss 2.398983
# batch 465: loss 2.679692
# batch 466: loss 2.692384
# batch 467: loss 2.460165
# batch 468: loss 2.961888
# batch 469: loss 2.551686
# batch 470: loss 2.701479
# batch 471: loss 2.395881
# batch 472: loss 2.330281
# batch 473: loss 2.879756
# batch 474: loss 2.594390
# batch 475: loss 2.397078
# batch 476: loss 2.737885
# batch 477: loss 2.513423
# batch 478: loss 2.790415
# batch 479: loss 2.649975
# batch 480: loss 2.757680
# batch 481: loss 2.733696
# batch 482: loss 2.456480
# batch 483: loss 2.711732
# batch 484: loss 2.621388
# batch 485: loss 2.672776
# batch 486: loss 2.521879
# batch 487: loss 2.570962
# batch 488: loss 2.510527
# batch 489: loss 2.804821
# batch 490: loss 2.603073
# batch 491: loss 2.619349
# batch 492: loss 2.388698
# batch 493: loss 2.479482
# batch 494: loss 2.509094
# batch 495: loss 2.828171
# batch 496: loss 2.619471
# batch 497: loss 2.679172
# batch 498: loss 2.660757
# batch 499: loss 2.768691
# batch 500: loss 2.564326
# batch 501: loss 2.787236
# batch 502: loss 2.660250
# batch 503: loss 2.714990
# batch 504: loss 2.598712
# batch 505: loss 2.876026
# batch 506: loss 2.654867
# batch 507: loss 2.596972
# batch 508: loss 2.432443
# batch 509: loss 2.776627
# batch 510: loss 2.496250
# batch 511: loss 2.556461
# batch 512: loss 2.623979
# batch 513: loss 2.432521
# batch 514: loss 2.794919
# batch 515: loss 2.957678
# batch 516: loss 2.594511
# batch 517: loss 2.665902
# batch 518: loss 2.367393
# batch 519: loss 2.586245
# batch 520: loss 2.317250
# batch 521: loss 2.809682
# batch 522: loss 2.704242
# batch 523: loss 2.681207
# batch 524: loss 2.742375
# batch 525: loss 2.608862
# batch 526: loss 3.027020
# batch 527: loss 2.564578
# batch 528: loss 2.827135
# batch 529: loss 2.338881
# batch 530: loss 2.639341
# batch 531: loss 2.654514
# batch 532: loss 2.681008
# batch 533: loss 2.542166
# batch 534: loss 2.271210
# batch 535: loss 2.617351
# batch 536: loss 2.861011
# batch 537: loss 2.700248
# batch 538: loss 2.412900
# batch 539: loss 2.455407
# batch 540: loss 2.665934
# batch 541: loss 2.616159
# batch 542: loss 2.507728
# batch 543: loss 3.150061
# batch 544: loss 2.531608
# batch 545: loss 2.510020
# batch 546: loss 2.445256
# batch 547: loss 2.348325
# batch 548: loss 2.347275
# batch 549: loss 2.721510
# batch 550: loss 2.674068
# batch 551: loss 2.405923
# batch 552: loss 2.738116
# batch 553: loss 2.584428
# batch 554: loss 2.805133
# batch 555: loss 2.438443
# batch 556: loss 2.635412
# batch 557: loss 2.483253
# batch 558: loss 2.871863
# batch 559: loss 2.752346
# batch 560: loss 2.456152
# batch 561: loss 3.041924
# batch 562: loss 2.647168
# batch 563: loss 2.869617
# batch 564: loss 2.709187
# batch 565: loss 2.807487
# batch 566: loss 2.266579
# batch 567: loss 2.418321
# batch 568: loss 2.804006
# batch 569: loss 2.398590
# batch 570: loss 2.786515
# batch 571: loss 2.546784
# batch 572: loss 2.394475
# batch 573: loss 2.589833
# batch 574: loss 2.388424
# batch 575: loss 2.807658
# batch 576: loss 2.433959
# batch 577: loss 2.420849
# batch 578: loss 2.616828
# batch 579: loss 2.515823
# batch 580: loss 2.622286
# batch 581: loss 2.789845
# batch 582: loss 2.704148
# batch 583: loss 2.400177
# batch 584: loss 2.782109
# batch 585: loss 2.472907
# batch 586: loss 2.848014
# batch 587: loss 2.497006
# batch 588: loss 2.383645
# batch 589: loss 2.234480
# batch 590: loss 2.434490
# batch 591: loss 2.482988
# batch 592: loss 2.538533
# batch 593: loss 2.601357
# batch 594: loss 2.373323
# batch 595: loss 2.439176
# batch 596: loss 2.453400
# batch 597: loss 2.430525
# batch 598: loss 2.661509
# batch 599: loss 2.298610
# batch 600: loss 2.162877
# batch 601: loss 2.291003
# batch 602: loss 2.323371
# batch 603: loss 2.499999
# batch 604: loss 2.414185
# batch 605: loss 2.531394
# batch 606: loss 2.406075
# batch 607: loss 2.825927
# batch 608: loss 2.642716
# batch 609: loss 2.693666
# batch 610: loss 2.539286
# batch 611: loss 2.616435
# batch 612: loss 2.350869
# batch 613: loss 2.452700
# batch 614: loss 2.370388
# batch 615: loss 2.536733
# batch 616: loss 2.259377
# batch 617: loss 2.556394
# batch 618: loss 2.478749
# batch 619: loss 2.268614
# batch 620: loss 2.525039
# batch 621: loss 2.346937
# batch 622: loss 2.610772
# batch 623: loss 2.374406
# batch 624: loss 2.446343
# batch 625: loss 2.742262
# batch 626: loss 2.648598
# batch 627: loss 2.310631
# batch 628: loss 2.544184
# batch 629: loss 2.751509
# batch 630: loss 2.698805
# batch 631: loss 2.206904
# batch 632: loss 2.524607
# batch 633: loss 2.861363
# batch 634: loss 2.384070
# batch 635: loss 2.319186
# batch 636: loss 2.356405
# batch 637: loss 2.755080
# batch 638: loss 2.323068
# batch 639: loss 2.574033
# batch 640: loss 2.532727
# batch 641: loss 2.432350
# batch 642: loss 2.294866
# batch 643: loss 2.443270
# batch 644: loss 2.581941
# batch 645: loss 2.636455
# batch 646: loss 2.454887
# batch 647: loss 2.352369
# batch 648: loss 2.539554
# batch 649: loss 2.541788
# batch 650: loss 2.416178
# batch 651: loss 2.500519
# batch 652: loss 2.466717
# batch 653: loss 2.592969
# batch 654: loss 2.763788
# batch 655: loss 2.467700
# batch 656: loss 2.295520
# batch 657: loss 2.487202
# batch 658: loss 2.383637
# batch 659: loss 2.138266
# batch 660: loss 2.374686
# batch 661: loss 2.612800
# batch 662: loss 2.129708
# batch 663: loss 2.491547
# batch 664: loss 2.363216
# batch 665: loss 2.488774
# batch 666: loss 2.610383
# batch 667: loss 2.463721
# batch 668: loss 2.607595
# batch 669: loss 2.552125
# batch 670: loss 2.321423
# batch 671: loss 2.476964
# batch 672: loss 2.567906
# batch 673: loss 2.529045
# batch 674: loss 2.468402
# batch 675: loss 2.837845
# batch 676: loss 2.733996
# batch 677: loss 2.455774
# batch 678: loss 2.392559
# batch 679: loss 2.645655
# batch 680: loss 2.417788
# batch 681: loss 2.275877
# batch 682: loss 2.696066
# batch 683: loss 2.463144
# batch 684: loss 2.473191
# batch 685: loss 2.585748
# batch 686: loss 2.606955
# batch 687: loss 2.587306
# batch 688: loss 2.254942
# batch 689: loss 2.459496
# batch 690: loss 2.666854
# batch 691: loss 2.254451
# batch 692: loss 2.513952
# batch 693: loss 2.689889
# batch 694: loss 2.460824
# batch 695: loss 2.451793
# batch 696: loss 2.753244
# batch 697: loss 2.681765
# batch 698: loss 2.665830
# batch 699: loss 2.578208
# batch 700: loss 2.631638
# batch 701: loss 2.465408
# batch 702: loss 2.527635
# batch 703: loss 2.544402
# batch 704: loss 2.602206
# batch 705: loss 2.430074
# batch 706: loss 2.701574
# batch 707: loss 2.355726
# batch 708: loss 2.181074
# batch 709: loss 2.718601
# batch 710: loss 2.658363
# batch 711: loss 2.572780
# batch 712: loss 2.357079
# batch 713: loss 2.422470
# batch 714: loss 2.540914
# batch 715: loss 2.500938
# batch 716: loss 2.668042
# batch 717: loss 2.538578
# batch 718: loss 2.298408
# batch 719: loss 2.801838
# batch 720: loss 2.539178
# batch 721: loss 2.470492
# batch 722: loss 2.472344
# batch 723: loss 2.449431
# batch 724: loss 2.162543
# batch 725: loss 2.269225
# batch 726: loss 2.358179
# batch 727: loss 2.526231
# batch 728: loss 2.677406
# batch 729: loss 2.514194
# batch 730: loss 2.599657
# batch 731: loss 2.798709
# batch 732: loss 2.378474
# batch 733: loss 2.194011
# batch 734: loss 2.444551
# batch 735: loss 2.453563
# batch 736: loss 2.307178
# batch 737: loss 2.185843
# batch 738: loss 2.151405
# batch 739: loss 2.411634
# batch 740: loss 2.440087
# batch 741: loss 2.421892
# batch 742: loss 2.295770
# batch 743: loss 2.552506
# batch 744: loss 2.529940
# batch 745: loss 2.513305
# batch 746: loss 2.378465
# batch 747: loss 2.249867
# batch 748: loss 2.542506
# batch 749: loss 2.545223
# batch 750: loss 2.293645
# batch 751: loss 2.362395
# batch 752: loss 2.161533
# batch 753: loss 2.475171
# batch 754: loss 2.697756
# batch 755: loss 2.484290
# batch 756: loss 2.205107
# batch 757: loss 2.531765
# batch 758: loss 2.472266
# batch 759: loss 2.411682
# batch 760: loss 2.477531
# batch 761: loss 2.345394
# batch 762: loss 2.109863
# batch 763: loss 2.312981
# batch 764: loss 2.366174
# batch 765: loss 2.303065
# batch 766: loss 2.328369
# batch 767: loss 2.344531
# batch 768: loss 2.380507
# batch 769: loss 2.647806
# batch 770: loss 2.282848
# batch 771: loss 2.423796
# batch 772: loss 2.617209
# batch 773: loss 1.960238
# batch 774: loss 2.546636
# batch 775: loss 2.738801
# batch 776: loss 2.195117
# batch 777: loss 2.304679
# batch 778: loss 2.548063
# batch 779: loss 2.691900
# batch 780: loss 2.494978
# batch 781: loss 2.326958
# batch 782: loss 2.355618
# batch 783: loss 2.225847
# batch 784: loss 2.319298
# batch 785: loss 2.761151
# batch 786: loss 2.251311
# batch 787: loss 2.456986
# batch 788: loss 2.365919
# batch 789: loss 2.429469
# batch 790: loss 2.533710
# batch 791: loss 2.740061
# batch 792: loss 2.265613
# batch 793: loss 2.819768
# batch 794: loss 2.800215
# batch 795: loss 1.918316
# batch 796: loss 2.316180
# batch 797: loss 2.355002
# batch 798: loss 2.475119
# batch 799: loss 2.230227
# batch 800: loss 2.520981
# batch 801: loss 2.629536
# batch 802: loss 2.692257
# batch 803: loss 2.170990
# batch 804: loss 2.493952
# batch 805: loss 2.269043
# batch 806: loss 2.751507
# batch 807: loss 2.514625
# batch 808: loss 2.126133
# batch 809: loss 2.535063
# batch 810: loss 2.199749
# batch 811: loss 2.433108
# batch 812: loss 2.684328
# batch 813: loss 2.446842
# batch 814: loss 2.585493
# batch 815: loss 2.523562
# batch 816: loss 2.332757
# batch 817: loss 2.141973
# batch 818: loss 2.262864
# batch 819: loss 2.228774
# batch 820: loss 2.363610
# batch 821: loss 2.412735
# batch 822: loss 2.662205
# batch 823: loss 2.819184
# batch 824: loss 2.199957
# batch 825: loss 2.482465
# batch 826: loss 2.506261
# batch 827: loss 2.567342
# batch 828: loss 2.194681
# batch 829: loss 2.593233
# batch 830: loss 2.310690
# batch 831: loss 2.434764
# batch 832: loss 2.577690
# batch 833: loss 2.479830
# batch 834: loss 2.219721
# batch 835: loss 2.769853
# batch 836: loss 2.482295
# batch 837: loss 2.460998
# batch 838: loss 2.185134
# batch 839: loss 2.687799
# batch 840: loss 2.363132
# batch 841: loss 2.259689
# batch 842: loss 2.611426
# batch 843: loss 2.581051
# batch 844: loss 2.682245
# batch 845: loss 2.584862
# batch 846: loss 2.492661
# batch 847: loss 2.366597
# batch 848: loss 2.297629
# batch 849: loss 2.630193
# batch 850: loss 2.509130
# batch 851: loss 2.370147
# batch 852: loss 2.300897
# batch 853: loss 2.469796
# batch 854: loss 2.630605
# batch 855: loss 2.448791
# batch 856: loss 2.175606
# batch 857: loss 2.408145
# batch 858: loss 2.297995
# batch 859: loss 2.790844
# batch 860: loss 2.366408
# batch 861: loss 2.462066
# batch 862: loss 2.365958
# batch 863: loss 2.370378
# batch 864: loss 2.749510
# batch 865: loss 2.400811
# batch 866: loss 2.762898
# batch 867: loss 2.658974
# batch 868: loss 2.608269
# batch 869: loss 2.277158
# batch 870: loss 2.474543
# batch 871: loss 2.161455
# batch 872: loss 2.361470
# batch 873: loss 2.915984
# batch 874: loss 2.177990
# batch 875: loss 2.266025
# batch 876: loss 2.393518
# batch 877: loss 2.506203
# batch 878: loss 2.463858
# batch 879: loss 2.514729
# batch 880: loss 2.705090
# batch 881: loss 2.301630
# batch 882: loss 2.194482
# batch 883: loss 2.023522
# batch 884: loss 2.392662
# batch 885: loss 2.628978
# batch 886: loss 2.350171
# batch 887: loss 2.429404
# batch 888: loss 2.232759
# batch 889: loss 2.601809
# batch 890: loss 2.095448
# batch 891: loss 2.437680
# batch 892: loss 2.321286
# batch 893: loss 2.240104
# batch 894: loss 2.350131
# batch 895: loss 2.421815
# batch 896: loss 2.460249
# batch 897: loss 2.390423
# batch 898: loss 2.401216
# batch 899: loss 2.385568
# batch 900: loss 2.255445
# batch 901: loss 2.320725
# batch 902: loss 2.413261
# batch 903: loss 2.285440
# batch 904: loss 2.415155
# batch 905: loss 2.121494
# batch 906: loss 2.615908
# batch 907: loss 2.412026
# batch 908: loss 2.638503
# batch 909: loss 2.407191
# batch 910: loss 2.424926
# batch 911: loss 2.608054
# batch 912: loss 2.488901
# batch 913: loss 2.337752
# batch 914: loss 2.262512
# batch 915: loss 2.208853
# batch 916: loss 2.029272
# batch 917: loss 2.499627
# batch 918: loss 2.552567
# batch 919: loss 2.524074
# batch 920: loss 2.295582
# batch 921: loss 2.395298
# batch 922: loss 2.291867
# batch 923: loss 2.684401
# batch 924: loss 2.450257
# batch 925: loss 2.573373
# batch 926: loss 2.280673
# batch 927: loss 2.212760
# batch 928: loss 2.693818
# batch 929: loss 2.288630
# batch 930: loss 2.234668
# batch 931: loss 2.232746
# batch 932: loss 2.440091
# batch 933: loss 2.547346
# batch 934: loss 2.336467
# batch 935: loss 2.300159
# batch 936: loss 2.454650
# batch 937: loss 2.385699
# batch 938: loss 2.635279
# batch 939: loss 2.328277
# batch 940: loss 2.273648
# batch 941: loss 2.102623
# batch 942: loss 2.156214
# batch 943: loss 2.494540
# batch 944: loss 2.421328
# batch 945: loss 2.518078
# batch 946: loss 2.417105
# batch 947: loss 2.322572
# batch 948: loss 2.726558
# batch 949: loss 2.561180
# batch 950: loss 2.108939
# batch 951: loss 2.236577
# batch 952: loss 2.216887
# batch 953: loss 2.426892
# batch 954: loss 2.592084
# batch 955: loss 2.350889
# batch 956: loss 2.545084
# batch 957: loss 2.615004
# batch 958: loss 2.091876
# batch 959: loss 2.440678
# batch 960: loss 1.966002
# batch 961: loss 2.318040
# batch 962: loss 2.319493
# batch 963: loss 2.161011
# batch 964: loss 2.252234
# batch 965: loss 2.711870
# batch 966: loss 2.363204
# batch 967: loss 2.629794
# batch 968: loss 2.290379
# batch 969: loss 2.675920
# batch 970: loss 1.788442
# batch 971: loss 2.545069
# batch 972: loss 2.112675
# batch 973: loss 2.383766
# batch 974: loss 2.701448
# batch 975: loss 2.610182
# batch 976: loss 2.078197
# batch 977: loss 2.176054
# batch 978: loss 2.449661
# batch 979: loss 2.643644
# batch 980: loss 2.313212
# batch 981: loss 2.197473
# batch 982: loss 2.573556
# batch 983: loss 2.473809
# batch 984: loss 2.461260
# batch 985: loss 2.119012
# batch 986: loss 2.544853
# batch 987: loss 2.165802
# batch 988: loss 2.353686
# batch 989: loss 2.744844
# batch 990: loss 2.273322
# batch 991: loss 2.415090
# batch 992: loss 2.134824
# batch 993: loss 2.303261
# batch 994: loss 2.686472
# batch 995: loss 2.378317
# batch 996: loss 2.250457
# batch 997: loss 2.508191
# batch 998: loss 2.381721
# batch 999: loss 2.459155

# %%
X_, _ = data_loader.get_batch(seq_length, 1)
for diversity in [0.2, 0.5, 1.0, 1.2]:      # 丰富度（即temperature）分别设置为从小到大的 4 个值
    X = X_
    print("diversity %f:" % diversity)
    for t in range(400):
        y_pred = model.predict(X, diversity)    # 预测下一个字符的编号
        print(data_loader.indices_char[y_pred[0]], end='', flush=True)  # 输出预测的字符
        X = np.concatenate([X[:, 1:], np.expand_dims(y_pred, axis=1)], axis=-1)     # 将预测的字符接在输入 X 的末尾，并截断 X 的第一个字符，以保证 X 的长度不变
    print("\n")
# Out:
# diversity 0.200000:
#  the he the the the the tha the the seresting of the ind and and the the the the he the the the the the the sore the for the the the sore the the sore the sint of the soul the the the somering of the the sore the the the woun the the the sore the sore the thithe the the the wor the the the sont in the the the the the the the the the the the sores and and and in the here the sore the woul on the th
#
# diversity 0.500000:
#  the land whan we fore th the thime and the tanct in the hele touctomo fhin to with werersthe the berhe mond ind ond of the the sore, and the the the toung so s th of berereng of the alis cous wo is the sere
# the with the the besn, on par whe fams ad lersaling and int fill wo this er ind tiun ion the poust of mirlsed th the loncist an thire the mont and of th ce rericoplinn ind momerser
# the sos ith
#
# diversity 1.000000:
#  thee fontt and aprerey. io  "uelantofothad to the torali-:aind brey in. . f lome si lo tiemdor ther ravdint, con ganitt ind sto lxidpoinils, the prolind fonf os aipterd-monl, an fo g int of
# thingdrong
#
# fheass
# and in bimlginca ay bnity
#
# fnthor -anl ls th =or thob
# simldewg. catis and laswit dend ye inse pe surop se bout an the weopesuneraty sosgin peting th restrtosoud ai
# wriny wof brerihy ardirsti
#
# diversity 1.200000:
# ve owelwaa;,
# p" morote2inpthpvrst, mathestof-]-nite seac-7uned ibsojt, wol cil sëda t ochmansesdirfeqnelitod
# bm bise
# ce wemultidryyeinlpy,f, mod erpr isedcidk
# eruld he moncs ferpewinerd,
# aou,goutobersr., anm undly,nw oust anliederptakute therprilknad,iinn. ab. corch8
# cennaro= gu5acs, fopstercty foce, ithinrud athcerdirtscinsikly-hom
# lbotesi ist
# "haw",ne
# .act wefralinn'trongbkelrpevirjts
# itg it ay
